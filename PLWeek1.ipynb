# %% [markdown]
# # Hello, World! - Introduction to Python

# %% [markdown]
# ## Print

# %% [markdown]
# We can use **print()** to 'print' anything.

# %% [markdown]
# ▶️ Run the code cell below to make system to print out a message!

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ▶️ Run the code cell below to make system to print out different things!

# %%
print(123)
print(5.5)
print(False)
# Out:
# 123
# 5.5
# False

# %% [markdown]
# ## Variables

# %% [markdown]
# We can declare variable by **(Name) = (Value)**.

# %%
name = "Jaehong"
age = 22
is_male = True

print(name)
print(age)
print(is_male)

# We can print different messages together in a single print statement!
print(name, age, is_male)
# Out:
# Jaehong
# 22
# True
# Jaehong 22 True

# %% [markdown]
# We can later change the value of the declared variable.

# %%
print(name, age)

name = "Hangoo"
age = 20

print(name, age, is_male)
# Out:
# Jaehong 22
# Hangoo 20 True

# %% [markdown]
# There can be many different types of variable!

# %% [markdown]
# **String** is a group of characters surrounded by ' ' or " ".
#
#
# ```
# "ABC"
# ```

# %% [markdown]
# **Integer** is a number without decimal points.
#
#
#
# ```
# 1
# ```

# %% [markdown]
# **Boolean** can be either *True* or *False*.
#
#
#
# ```
# True
# ```

# %% [markdown]
# **Float** is a number with decimal points.
#
#
#
# ```
# 1.2
# ```

# %% [markdown]
# Lets find out the type of variables using **type()**!

# %%
a = "name"
print(type(a))

a = 2
print(type(a))

a = False
print(type(a))

a = 2.333
print(type(a))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'bool'>
# <class 'float'>

# %%
inte = 4

string_int = "4"
print( inte + string_int)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-6b93cedc7f82> in <cell line: 4>()
#       2
#       3 string_int = "4"
# ----> 4 print( inte + string_int)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# variable_name = variable_value

# %% [markdown]
# ###🎯 Challenge 1

# %%
a = 'one'
b = 'two'

# Change the value of a and b! But you cannot make a to 'two' and b to 'one'.

# YOUR CODE HERE #

# END OF CODE #

print('Value of a is', a)
print('Value of b is', b)
# Out:
# Value of a is one
# Value of b is two

# %% [markdown]
# ##Basic Operators

# %% [markdown]
# We can use **[ +, -, **, /, //, ***, % ]** to do arithmetics.

# %%
num_1 = 4
num_2 = 2

# Change the '+' sign to check the result!
print(num_1 / num_2)


# Modulus -> Gets the remainder
print(14 % 6)

# Floor Division -> Rounds the result down to the nearest integer
print(14 // 6)
# Out:
# 2.0
# 2
# 2

# %% [markdown]
# We can use **[ >, >=, <, <= ]** to do comparison.

# %%
# Change the '<' sign to check the result!
print(num_1 < num_2)
# Out:
# False

# %% [markdown]
# We can do arithmetics and assignment together by **[ +=, -=, *=, /= ]**.

# %%
print(num_1)

# num_1 = num_1 + 3
# Change the '+=' sign to check the result!
num_1 += 5

print(num_1)

# %% [markdown]
# We can do boolean operations by **[ ==, != ]**.

# %%
print(1 + 1 == 2)

print(2 + 2 != 4)
# Out:
# True
# False

# %% [markdown]
# We can also do boolean operations by **[ not, or, and ]**.

# %%
t = True
f = False

# True when all inputs are true
print(t and f)

# True when at least one input is true
print(t or f)

# True when input is false
print(not t)
# Out:
# False
# True
# False

# %% [markdown]
# ##Comment

# %% [markdown]
# We can use '#' sign to write comments in Python.
#
# ```
# # This is comment
# ####### This is comment
# # T # h # i #s...
# ```

# %% [markdown]
# But why do we use comments?

# %% [markdown]
# ###To explain code

# %%
# Code that prints out "Hello World!"
print("Hello world")

# %% [markdown]
# ###To nullify code

# %%
print(0)
#print(1)
print(2)
#print(3)
print(4)
#print(5)
# Out:
# 0
# 2
# 4

# %% [markdown]
# ###To write memo

# %%
# You don't have to understand the code!

import numpy as np
import numpy.linalg as la

def fea_solve(Kpp,Kpf,Kfp,Kff,xp,Ff):
    xf = la.solve(Kff, Ff - (Kfp @ xp))

    # Can you please explain this line plz...
    Fp = (Kpp @ xp) + (Kpf @ xf)

    # TODO: finish this function
    return xf,Fp
